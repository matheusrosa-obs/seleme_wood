# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pd.read_csv(r"C:\Projetos\Nova pasta\seleme_wood\App\items_final.csv").columns
# Out:
# Index(['nome_empresa', 'url_site', 'data_coleta', 'categoria_produto',
#        'nome_produto', 'material', 'relacionado_madeira', 'menciona_pinus',
#        'fonte_indicio', 'categoria_produto_norm', 'categoria_produto_grupo',
#        'material_norm', 'material_grupo'],
#       dtype='object')

# %%
pd.read_csv(r"C:\Projetos\Nova pasta\seleme_wood\App\companies_final.csv").columns
# Out:
# Index(['nome_empresa', 'url_site', 'consulta', 'status_execucao',
#        'mensagem_pt', 'trabalha_com_madeira', 'trabalha_com_painel_pinus',
#        'flag_painel_pinus', 'confianca_madeira', 'confianca_painel_pinus',
#        'trecho_evidencia', 'resumo_materiais', 'qtde_itens_total',
#        'qtde_itens_madeira', 'qtde_itens_menciona_pinus', 'data_coleta',
#        'tentativas', 'nome_empresa_limpa', 'nm_mun', 'nm_uf', 'nu_latitude',
#        'nu_longitude'],
#       dtype='object')

# %%
df_companies_sc = pd.read_csv(r"C:\Projetos\Nova pasta\seleme_wood\App\portfolio\companies_sc.csv")
df_companies_pr = pd.read_csv(r"C:\Projetos\Nova pasta\seleme_wood\App\portfolio\companies_pr.csv")
df_companies_rs = pd.read_csv(r"C:\Projetos\Nova pasta\seleme_wood\App\portfolio\companies_rs.csv")

COLUNAS_PT_2 = {
    "nm_empresa": "nome_empresa",
    "website_url": "url_site",
    "query": "consulta",

    "status": "status_execucao",
    "message_pt": "mensagem_pt",

    "works_with_wood": "trabalha_com_madeira",
    "works_with_pine_panel": "trabalha_com_painel_pinus",
    "pine_panel_flag": "flag_painel_pinus",

    "confidence_wood": "confianca_madeira",
    "confidence_pine_panel": "confianca_painel_pinus",

    "evidence_snippet": "trecho_evidencia",
    "materials_summary": "resumo_materiais",

    "item_count_total": "qtde_itens_total",
    "item_count_wood_related": "qtde_itens_madeira",
    "item_count_mentions_pinus": "qtde_itens_menciona_pinus",

    "run_at": "data_coleta",
    "attempts": "tentativas"
}

df_companies_pr = df_companies_pr.rename(columns=COLUNAS_PT_2)
df_companies_rs = df_companies_rs.rename(columns=COLUNAS_PT_2)
df_companies_sc = df_companies_sc.rename(columns=COLUNAS_PT_2)


df_companies = pd.concat([df_companies_sc, df_companies_pr, df_companies_rs], ignore_index=True)

# %%
df_companies
# Out:
#                                           nome_empresa  \
# 0    Esquadribras - Industria De Esquadrias Ltda - ...
# 1                          Klabin S.A. - Pouso Redondo
# 2    Sul America Industria De Molduras - Braco do N...
# 3        Blue Forest Industria E Comercio Ltda - Lages
# 4    Lavradora Racional De Madeiras Lavrama Sa - Ti...
# ..                                                 ...
# 608    Roal Industria Metalurgica Ltda - Caxias do Sul
# 609                                   C.C.L. - Lajeado
# 610                                    Homestar Brasil
# 611                 Moveis Bosi Ltda - Bento Goncalves
# 612                      ****** - Sao Joao do Polesine
#
#                                   url_site                 consulta  \
# 0         https://www.esquadribras.com.br/  painel de madeira pinus
# 1                   https://klabin.com.br/  painel de madeira pinus
# 2    https://www.sulamericamolduras.com.br  painel de madeira pinus
# 3                https://blueforest.com.br  painel de madeira pinus
# 4              https://www.lavrama.com.br/  painel de madeira pinus
# ..                                     ...                      ...
# 608               https://roaltech.com.br/  painel de madeira pinus
# 609          https://www.cclajeado.com.br/  painel de madeira pinus
# 610           https://www.homestar.com.br/  painel de madeira pinus
# 611               https://www.bosi.com.br/  painel de madeira pinus
# 612   https://saojoaodopolesine.rs.gov.br/  painel de madeira pinus
#
#     status_execucao                                        mensagem_pt  \
# 0             FOUND  Informações sobre produtos de madeira e painéi...
# 1             FOUND  Informações sobre produtos de madeira e painéi...
# 2             FOUND  Produtos relacionados a madeira e painéis de p...
# 3             FOUND  Informações sobre produtos de madeira pinus en...
# 4             FOUND  Empresa encontrada com informações sobre produ...
# ..              ...                                                ...
# 608       NOT_FOUND  Não foram encontradas informações sobre trabal...
# 609       NOT_FOUND  O site é de uma igreja e não há informações so...
# 610           FOUND  Produtos encontrados que imitam madeira, mas s...
# 611           ERROR                 Erro ao processar: ValidationError
# 612           ERROR                         Erro ao processar: OSError
#
#     trabalha_com_madeira trabalha_com_painel_pinus  flag_painel_pinus  \
# 0                    yes                       yes                  1
# 1                    yes                       yes                  1
# 2                    yes                       yes                  1
# 3                    yes                       yes                  1
# 4                    yes                       yes                  1
# ..                   ...                       ...                ...
# 608                   no                        no                  0
# 609                   no                        no                  0
# 610                   no                        no                  0
# 611              unknown                   unknown                  0
# 612              unknown                   unknown                  0
#
#      confianca_madeira  confianca_painel_pinus  \
# 0                  100                     100
# 1                  100                     100
# 2                  100                     100
# 3                  100                     100
# 4                  100                     100
# ..                 ...                     ...
# 608                  5                       5
# 609                  5                       5
# 610                  5                       5
# 611                  0                       0
# 612                  0                       0
#
#                                       trecho_evidencia  \
# 0    A empresa oferece produtos como 'Portas Pínus ...
# 1    Papel Kraftliner: Produzido a partir de uma mi...
# 2    Painel Redondo de Pinus\nPainel Pinus Fingado ...
# 3    CERCAS BRUTAS DE PINUS "DOG EAR"\nCERCAS GÓTIC...
# 4    A lavrama pertence ao grupo de empresas fundad...
# ..                                                 ...
# 608  A empresa é especializada em oferecer soluções...
# 609  O site pertence à Comunidade Cristã de Lajeado...
# 610  Vigas de poliuretano HOMESTAR, também são conh...
# 611                            Falha no processamento.
# 612                            Falha no processamento.
#
#                                       resumo_materiais  qtde_itens_total  \
# 0    A empresa trabalha com portas feitas de Pinus ...                 7
# 1    A Klabin fabrica produtos como Papel Kraftline...                11
# 2    A empresa trabalha com painéis de Pinus (Finga...                 7
# 3    A empresa oferece diversos produtos de madeira...                 7
# 4    A empresa produz molduras, painéis colados de ...                 7
# ..                                                 ...               ...
# 608  A empresa foca em soluções metálicas, como cor...                 0
# 609  Não foram encontrados materiais relacionados a...                 0
# 610  Os produtos nesta categoria são feitos de poli...                 9
# 611                                                NaN                 0
# 612                                                NaN                 0
#
#      qtde_itens_madeira  qtde_itens_menciona_pinus  \
# 0                     4                          4
# 1                    11                         10
# 2                     7                          6
# 3                     7                          5
# 4                     7                          3
# ..                  ...                        ...
# 608                   0                          0
# 609                   0                          0
# 610                   9                          0
# 611                   0                          0
# 612                   0                          0
#
#                           data_coleta  \
# 0    2026-01-15T12:28:56.581992+00:00
# 1    2026-01-15T12:48:01.397078+00:00
# 2    2026-01-15T12:52:46.184676+00:00
# 3    2026-01-15T12:54:53.981357+00:00
# 4    2026-01-15T13:08:08.993450+00:00
# ..                                ...
# 608  2026-01-26T18:47:05.415393+00:00
# 609  2026-01-26T18:47:09.876283+00:00
# 610  2026-01-26T18:47:39.741201+00:00
# 611  2026-01-26T17:25:11.781618+00:00
# 612  2026-01-26T17:58:12.357214+00:00
#
#                                             tentativas
# 0    https://www.esquadribras.com.br/; https://www....
# 1    Navigated to https://klabin.com.br/; Clicked '...
# 2    Navigated to https://www.sulamericamolduras.co...
# 3    Navigated to https://blueforest.com.br; Clicke...
# 4    Navigated to https://www.lavrama.com.br/; Extr...
# ..                                                 ...
# 608  Navigated to https://roaltech.com.br/; Scrolle...
# 609  Navigated to https://www.cclajeado.com.br/; Ac...
# 610  Navigated to Homestar Brasil.; Clicked on 'Pro...
# 611                                                NaN
# 612                                                NaN
#
# [613 rows x 17 columns]

# %%
df_itens_sc = pd.read_csv(r"C:\Projetos\Nova pasta\seleme_wood\App\portfolio\items_sc.csv")
df_itens_pr = pd.read_csv(r"C:\Projetos\Nova pasta\seleme_wood\App\portfolio\items_pr.csv")
df_itens_rs = pd.read_csv(r"C:\Projetos\Nova pasta\seleme_wood\App\portfolio\items_rs.csv")

COLUNAS_PT = {
    "nm_empresa": "nome_empresa",
    "website_url": "url_site",
    "run_at": "data_coleta",

    "product_category": "categoria_produto",
    "product_category_norm": "categoria_produto_norm",
    "product_category_grouped": "categoria_produto_grupo",

    "product_name": "nome_produto",

    "materials": "material",
    "materials_norm": "material_norm",
    "materials_grouped": "material_grupo",

    "is_wood_related": "relacionado_madeira",
    "mentions_pinus": "menciona_pinus",

    "source_hint": "fonte_indicio"
}
df_itens_pr = df_itens_pr.rename(columns=COLUNAS_PT)
df_itens_rs = df_itens_rs.rename(columns=COLUNAS_PT)
df_itens_sc = df_itens_sc.rename(columns=COLUNAS_PT)

df_itens = pd.concat([df_itens_sc, df_itens_pr, df_itens_rs], ignore_index=True)

# %%
df_itens
# Out:
#                                        nome_empresa  \
# 0     Blue Forest Industria E Comercio Ltda - Lages
# 1     Blue Forest Industria E Comercio Ltda - Lages
# 2     Blue Forest Industria E Comercio Ltda - Lages
# 3     Blue Forest Industria E Comercio Ltda - Lages
# 4     Blue Forest Industria E Comercio Ltda - Lages
# ...                                             ...
# 1899  Trianon Industria E Comercio Ltda - Garibaldi
# 1900  Trianon Industria E Comercio Ltda - Garibaldi
# 1901  Trianon Industria E Comercio Ltda - Garibaldi
# 1902  Trianon Industria E Comercio Ltda - Garibaldi
# 1903                                 Villa Imperial
#
#                                url_site                       data_coleta  \
# 0             https://blueforest.com.br  2026-01-15T12:54:53.981357+00:00
# 1             https://blueforest.com.br  2026-01-15T12:54:53.981357+00:00
# 2             https://blueforest.com.br  2026-01-15T12:54:53.981357+00:00
# 3             https://blueforest.com.br  2026-01-15T12:54:53.981357+00:00
# 4             https://blueforest.com.br  2026-01-15T12:54:53.981357+00:00
# ...                                 ...                               ...
# 1899    https://www.trianongroup.com.br  2026-01-26T17:33:56.339646+00:00
# 1900    https://www.trianongroup.com.br  2026-01-26T17:33:56.339646+00:00
# 1901    https://www.trianongroup.com.br  2026-01-26T17:33:56.339646+00:00
# 1902    https://www.trianongroup.com.br  2026-01-26T17:33:56.339646+00:00
# 1903  https://www.villaimperial.com.br/  2026-01-26T18:10:09.589325+00:00
#
#                              categoria_produto  \
# 0                                CERCAS BRUTAS
# 1                               CERCAS GÓTICAS
# 2                               CERCAS GÓTICAS
# 3                                      ESTACAS
# 4                                   BALAÚSTRES
# ...                                        ...
# 1899          Cápsulas e Screwcaps para vinhos
# 1900          Cápsulas e Screwcaps para vinhos
# 1901  Gabietas, cápsulas e Tampas de espumante
# 1902                       Esferas de Concreto
# 1903                        Fechamento Externo
#
#                                  nome_produto       material  \
# 0            CERCAS BRUTAS DE PINUS "DOG EAR"          PINUS
# 1              CERCAS GÓTICAS BRUTAS DE PINUS          PINUS
# 2          CERCAS GÓTICAS APLAINADAS DE PINUS          PINUS
# 3                 ESTACAS APLAINADAS DE PINUS          PINUS
# 4              BALAÚSTRES APLAINADOS DE PINUS          PINUS
# ...                                       ...            ...
# 1899           Cápsulas para Vinho em Estanho        Estanho
# 1900  Tampas De Alumínio Com Rosca (Screwcap)       Alumínio
# 1901                                 Gabietas            NaN
# 1902                      Esferas de Concreto  Concreto leve
# 1903                        Chapa de MDF 3 mm            MDF
#
#      relacionado_madeira menciona_pinus  \
# 0                    yes            yes
# 1                    yes            yes
# 2                    yes            yes
# 3                    yes            yes
# 4                    yes            yes
# ...                  ...            ...
# 1899                  no             no
# 1900                  no             no
# 1901                  no             no
# 1902                  no             no
# 1903                  no             no
#
#                                  fonte_indicio
# 0                              Mercado Externo
# 1                              Mercado Externo
# 2                              Mercado Externo
# 3                              Mercado Externo
# 4                              Mercado Externo
# ...                                        ...
# 1899          Cápsulas e Screwcaps para vinhos
# 1900          Cápsulas e Screwcaps para vinhos
# 1901  Gabietas, cápsulas e Tampas de espumante
# 1902                       Esferas de Concreto
# 1903                Madeira de reflorestamento
#
# [1904 rows x 9 columns]

# %%
df_itens['categoria_produto'].value_counts()
# Out:
# categoria_produto
# Product Category                            60
# Piso Laminado                               32
# Janelas                                     27
# Classic Wood                                27
# RECAMIER                                    24
#                                             ..
# Ferragens                                    1
# CERCAS BRUTAS                                1
# Gabietas, cápsulas e Tampas de espumante     1
# Esferas de Concreto                          1
# Fechamento Externo                           1
# Name: count, Length: 359, dtype: int64

# %% [markdown]
# ## Aplicando tratamento na coluna Categoria de Produto

# %%
import unidecode
import pandas as pd

def normalize_category(text):
    if pd.isna(text):
        return ""
    text = text.lower()
    text = unidecode.unidecode(text)
    text = text.strip()
    return text

df_itens["categoria_produto_norm"] = (
    df_itens["categoria_produto"]
        .astype(str)
        .apply(normalize_category)
)

# %%
def keyword_grouping(cat):
    if not cat:
        return "outros"

    # PORTAS
    if "porta" in cat:
        return "portas"
    
    if any(x in cat for x in ["painel", "paineis"]):
        return "painel"

    # MADEIRA
    if any(x in cat for x in ["wood", "madeira", "laminado", "Madeira", "Wood", "Classic Wood"]):
        return "madeira"

    # MÓVEIS
    if any(x in cat for x in [
        "mobil",        # pega mobiliario, mobiliarios
        "movel",        # pega movel, moveis
        "sofa",
        "poltrona",
        "cadeira",
        "mesa",
        "buffet",
        "cristaleira",
        "aparador",
        "rack",
        "estante",
        "painel",
        "home"
    ]):
        return "moveis"

    # FERRAMENTAS
    if "ferramenta" in cat:
        return "ferramentas"

    return "outros"

# %%
df_itens["categoria_produto_grupo"] = (
    df_itens["categoria_produto_norm"]
        .apply(keyword_grouping)
)

# %%
df_itens["categoria_produto"].value_counts().head(15)
# Out:
# categoria_produto
# Product Category                      60
# Piso Laminado                         32
# Janelas                               27
# Classic Wood                          27
# RECAMIER                              24
# Madeira                               23
# Mobiliário e utensílios               23
# Painéis / Estantes / Racks e Homes    23
# Roupeiros                             23
# Ferramentas                           23
# Linha Office                          22
# Salas de Jantar                       22
# Portas                                22
# Wood                                  20
# Cozinha                               18
# Name: count, dtype: int64

# %%
df_itens["categoria_produto_grupo"].value_counts()
# Out:
# categoria_produto_grupo
# outros         1413
# madeira         163
# moveis          153
# painel           90
# portas           62
# ferramentas      23
# Name: count, dtype: int64

# %%
(
    df_itens
    .loc[df_itens["categoria_produto_grupo"] == "outros", "categoria_produto"]
    .value_counts()
    .head(30)
)
# Out:
# categoria_produto
# Product Category                   60
# Janelas                            27
# RECAMIER                           24
# Roupeiros                          23
# Salas de Jantar                    22
# Linha Office                       22
# Cozinha                            18
# Acabamentos                        18
# Estrutura da obra                  15
# Not specified                      13
# AUDITÓRIOS, TEATROS                12
# Quarto                             12
# Furniture                          11
# CAMAS                              10
# ESPAÇOS RELIGIOSOS                 10
# Tipos de Produto                   10
# Pallets                             9
# Vigas | Tábuas | Suportes           9
# Compensados                         9
# Bedside tables                      9
# Roupeiro                            8
# Palete PBR                          8
# Rolhas para Vinhos e espumantes     8
# COZINHAS                            8
# Pisos                               8
# Construção Civil                    8
# Nicho                               7
# Componentes                         7
# Modular bedroom                     7
# Multiusos                           7
# Name: count, dtype: int64

# %%
df_itens
# Out:
#                                        nome_empresa  \
# 0     Blue Forest Industria E Comercio Ltda - Lages
# 1     Blue Forest Industria E Comercio Ltda - Lages
# 2     Blue Forest Industria E Comercio Ltda - Lages
# 3     Blue Forest Industria E Comercio Ltda - Lages
# 4     Blue Forest Industria E Comercio Ltda - Lages
# ...                                             ...
# 1899  Trianon Industria E Comercio Ltda - Garibaldi
# 1900  Trianon Industria E Comercio Ltda - Garibaldi
# 1901  Trianon Industria E Comercio Ltda - Garibaldi
# 1902  Trianon Industria E Comercio Ltda - Garibaldi
# 1903                                 Villa Imperial
#
#                                url_site                       data_coleta  \
# 0             https://blueforest.com.br  2026-01-15T12:54:53.981357+00:00
# 1             https://blueforest.com.br  2026-01-15T12:54:53.981357+00:00
# 2             https://blueforest.com.br  2026-01-15T12:54:53.981357+00:00
# 3             https://blueforest.com.br  2026-01-15T12:54:53.981357+00:00
# 4             https://blueforest.com.br  2026-01-15T12:54:53.981357+00:00
# ...                                 ...                               ...
# 1899    https://www.trianongroup.com.br  2026-01-26T17:33:56.339646+00:00
# 1900    https://www.trianongroup.com.br  2026-01-26T17:33:56.339646+00:00
# 1901    https://www.trianongroup.com.br  2026-01-26T17:33:56.339646+00:00
# 1902    https://www.trianongroup.com.br  2026-01-26T17:33:56.339646+00:00
# 1903  https://www.villaimperial.com.br/  2026-01-26T18:10:09.589325+00:00
#
#                              categoria_produto  \
# 0                                CERCAS BRUTAS
# 1                               CERCAS GÓTICAS
# 2                               CERCAS GÓTICAS
# 3                                      ESTACAS
# 4                                   BALAÚSTRES
# ...                                        ...
# 1899          Cápsulas e Screwcaps para vinhos
# 1900          Cápsulas e Screwcaps para vinhos
# 1901  Gabietas, cápsulas e Tampas de espumante
# 1902                       Esferas de Concreto
# 1903                        Fechamento Externo
#
#                                  nome_produto       material  \
# 0            CERCAS BRUTAS DE PINUS "DOG EAR"          PINUS
# 1              CERCAS GÓTICAS BRUTAS DE PINUS          PINUS
# 2          CERCAS GÓTICAS APLAINADAS DE PINUS          PINUS
# 3                 ESTACAS APLAINADAS DE PINUS          PINUS
# 4              BALAÚSTRES APLAINADOS DE PINUS          PINUS
# ...                                       ...            ...
# 1899           Cápsulas para Vinho em Estanho        Estanho
# 1900  Tampas De Alumínio Com Rosca (Screwcap)       Alumínio
# 1901                                 Gabietas            NaN
# 1902                      Esferas de Concreto  Concreto leve
# 1903                        Chapa de MDF 3 mm            MDF
#
#      relacionado_madeira menciona_pinus  \
# 0                    yes            yes
# 1                    yes            yes
# 2                    yes            yes
# 3                    yes            yes
# 4                    yes            yes
# ...                  ...            ...
# 1899                  no             no
# 1900                  no             no
# 1901                  no             no
# 1902                  no             no
# 1903                  no             no
#
#                                  fonte_indicio  \
# 0                              Mercado Externo
# 1                              Mercado Externo
# 2                              Mercado Externo
# 3                              Mercado Externo
# 4                              Mercado Externo
# ...                                        ...
# 1899          Cápsulas e Screwcaps para vinhos
# 1900          Cápsulas e Screwcaps para vinhos
# 1901  Gabietas, cápsulas e Tampas de espumante
# 1902                       Esferas de Concreto
# 1903                Madeira de reflorestamento
#
#                         categoria_produto_norm categoria_produto_grupo
# 0                                cercas brutas                  outros
# 1                               cercas goticas                  outros
# 2                               cercas goticas                  outros
# 3                                      estacas                  outros
# 4                                   balaustres                  outros
# ...                                        ...                     ...
# 1899          capsulas e screwcaps para vinhos                  outros
# 1900          capsulas e screwcaps para vinhos                  outros
# 1901  gabietas, capsulas e tampas de espumante                  outros
# 1902                       esferas de concreto                  outros
# 1903                        fechamento externo                  outros
#
# [1904 rows x 11 columns]

# %% [markdown]
# ## Coluna materias

# %%
print(df_itens['material'].value_counts())
# Out:
# material
# Not specified                                                        108
# Madeira                                                               97
# Unknown                                                               92
# Wood                                                                  52
# wood                                                                  37
#                                                                     ...
# Máquinas Dewalt e Stanley                                              1
# Painel Wall, Placa Piso em Fibrocimento e OSB APA Plus Estrutural      1
# Fibrocimento, OSB                                                      1
# Carpetes                                                               1
# Pinus, Eucalipto                                                       1
# Name: count, Length: 289, dtype: int64

# %%
import pandas as pd
import unidecode

def normalize_text(text):
    if pd.isna(text):
        return ""
    text = str(text).strip().lower()
    text = unidecode.unidecode(text)
    return text

df_itens["material_norm"] = df_itens["material"].apply(normalize_text)

# %%
def materials_grouping(mat):
    if not mat:
        return "Não especificado"

    # "não informado"
    if any(x in mat for x in ["not specified", "not informed", "nao especificado", "nao informado", "unknown", "n/a"]):
        return "Não especificado"

    # Pinus (prioridade antes de madeira genérica, se você quiser manter separado)
    if any(x in mat for x in ["pinus", "pine"]):
        return "Pinus"

    # Madeira (wood/madeira)
    if any(x in mat for x in ["wood", "madeira", "Wood"]):
        return "Madeira"

    # fallback: só padroniza capitalização básica
    # (mantém "pet" -> "Pet", "aco baixo carbono..." -> "Aco baixo carbono...")
    return mat[:1].upper() + mat[1:] if mat else "Não especificado"

# %%
df_itens
# Out:
#                                        nome_empresa  \
# 0     Blue Forest Industria E Comercio Ltda - Lages
# 1     Blue Forest Industria E Comercio Ltda - Lages
# 2     Blue Forest Industria E Comercio Ltda - Lages
# 3     Blue Forest Industria E Comercio Ltda - Lages
# 4     Blue Forest Industria E Comercio Ltda - Lages
# ...                                             ...
# 1899  Trianon Industria E Comercio Ltda - Garibaldi
# 1900  Trianon Industria E Comercio Ltda - Garibaldi
# 1901  Trianon Industria E Comercio Ltda - Garibaldi
# 1902  Trianon Industria E Comercio Ltda - Garibaldi
# 1903                                 Villa Imperial
#
#                                url_site                       data_coleta  \
# 0             https://blueforest.com.br  2026-01-15T12:54:53.981357+00:00
# 1             https://blueforest.com.br  2026-01-15T12:54:53.981357+00:00
# 2             https://blueforest.com.br  2026-01-15T12:54:53.981357+00:00
# 3             https://blueforest.com.br  2026-01-15T12:54:53.981357+00:00
# 4             https://blueforest.com.br  2026-01-15T12:54:53.981357+00:00
# ...                                 ...                               ...
# 1899    https://www.trianongroup.com.br  2026-01-26T17:33:56.339646+00:00
# 1900    https://www.trianongroup.com.br  2026-01-26T17:33:56.339646+00:00
# 1901    https://www.trianongroup.com.br  2026-01-26T17:33:56.339646+00:00
# 1902    https://www.trianongroup.com.br  2026-01-26T17:33:56.339646+00:00
# 1903  https://www.villaimperial.com.br/  2026-01-26T18:10:09.589325+00:00
#
#                              categoria_produto  \
# 0                                CERCAS BRUTAS
# 1                               CERCAS GÓTICAS
# 2                               CERCAS GÓTICAS
# 3                                      ESTACAS
# 4                                   BALAÚSTRES
# ...                                        ...
# 1899          Cápsulas e Screwcaps para vinhos
# 1900          Cápsulas e Screwcaps para vinhos
# 1901  Gabietas, cápsulas e Tampas de espumante
# 1902                       Esferas de Concreto
# 1903                        Fechamento Externo
#
#                                  nome_produto       material  \
# 0            CERCAS BRUTAS DE PINUS "DOG EAR"          PINUS
# 1              CERCAS GÓTICAS BRUTAS DE PINUS          PINUS
# 2          CERCAS GÓTICAS APLAINADAS DE PINUS          PINUS
# 3                 ESTACAS APLAINADAS DE PINUS          PINUS
# 4              BALAÚSTRES APLAINADOS DE PINUS          PINUS
# ...                                       ...            ...
# 1899           Cápsulas para Vinho em Estanho        Estanho
# 1900  Tampas De Alumínio Com Rosca (Screwcap)       Alumínio
# 1901                                 Gabietas            NaN
# 1902                      Esferas de Concreto  Concreto leve
# 1903                        Chapa de MDF 3 mm            MDF
#
#      relacionado_madeira menciona_pinus  \
# 0                    yes            yes
# 1                    yes            yes
# 2                    yes            yes
# 3                    yes            yes
# 4                    yes            yes
# ...                  ...            ...
# 1899                  no             no
# 1900                  no             no
# 1901                  no             no
# 1902                  no             no
# 1903                  no             no
#
#                                  fonte_indicio  \
# 0                              Mercado Externo
# 1                              Mercado Externo
# 2                              Mercado Externo
# 3                              Mercado Externo
# 4                              Mercado Externo
# ...                                        ...
# 1899          Cápsulas e Screwcaps para vinhos
# 1900          Cápsulas e Screwcaps para vinhos
# 1901  Gabietas, cápsulas e Tampas de espumante
# 1902                       Esferas de Concreto
# 1903                Madeira de reflorestamento
#
#                         categoria_produto_norm categoria_produto_grupo  \
# 0                                cercas brutas                  outros
# 1                               cercas goticas                  outros
# 2                               cercas goticas                  outros
# 3                                      estacas                  outros
# 4                                   balaustres                  outros
# ...                                        ...                     ...
# 1899          capsulas e screwcaps para vinhos                  outros
# 1900          capsulas e screwcaps para vinhos                  outros
# 1901  gabietas, capsulas e tampas de espumante                  outros
# 1902                       esferas de concreto                  outros
# 1903                        fechamento externo                  outros
#
#       material_norm
# 0             pinus
# 1             pinus
# 2             pinus
# 3             pinus
# 4             pinus
# ...             ...
# 1899        estanho
# 1900       aluminio
# 1901
# 1902  concreto leve
# 1903            mdf
#
# [1904 rows x 12 columns]

# %%
df_itens["material_grupo"] = df_itens["material_norm"].apply(materials_grouping)

# %%
df_itens["material"].value_counts().head(20)
# Out:
# material
# Not specified                                                 108
# Madeira                                                        97
# Unknown                                                        92
# Wood                                                           52
# wood                                                           37
# Pinus                                                          29
# Not mentioned                                                  17
# MDF                                                            16
# Eucalipto                                                      14
# MDF (implied by 100% MDF sticker on similar product image)     13
# MDF (for handles)                                              12
# MADEIRA                                                        12
# MDP                                                            11
# Fibras virgens de pinus e eucalipto                             9
# Poliuretano                                                     9
# Cortiça                                                         8
# Madeira maciça, PET, HDF                                        8
# Madeiras                                                        8
# MADEIRA MACIÇA                                                  8
# Madeira 100% reflorestada                                       7
# Name: count, dtype: int64

# %%
df_itens["material_grupo"].value_counts().head(20)
# Out:
# material_grupo
# Não especificado                                              1146
# Madeira                                                        320
# Pinus                                                          119
# Not mentioned                                                   17
# Mdf                                                             16
# Eucalipto                                                       14
# Mdf (implied by 100% mdf sticker on similar product image)      13
# Mdf (for handles)                                               12
# Mdp                                                             11
# Poliuretano                                                      9
# Freijo                                                           8
# Cortica                                                          8
# Teka, green jade                                                 7
# Mdf wall panels.                                                 6
# Cedro                                                            5
# Ferro                                                            4
# Carvalho (oak)                                                   4
# Nature                                                           4
# Hdf                                                              4
# Mdf, vidro                                                       3
# Name: count, dtype: int64

# %%
df_itens.loc[
    ~df_itens["material_grupo"].isin(["Madeira", "Pinus", "Não especificado"]),
    "material"
].value_counts().head(30)
# Out:
# material
# Not mentioned                                                 17
# MDF                                                           16
# Eucalipto                                                     14
# MDF (implied by 100% MDF sticker on similar product image)    13
# MDF (for handles)                                             12
# MDP                                                           11
# Poliuretano                                                    9
# Cortiça                                                        8
# Teka, Green Jade                                               7
# FREIJO                                                         6
# MDF wall panels.                                               6
# CEDRO                                                          5
# Ferro                                                          4
# HDF                                                            4
# NATURE                                                         4
# Carvalho (Oak)                                                 4
# Aço                                                            3
# PVC                                                            3
# MDF, vidro                                                     3
# CINAMOMO                                                       3
# Carvalho                                                       3
# Jatobá                                                         2
# Tauari                                                         2
# Carvalho Latino                                                2
# Sucupira                                                       2
# Ipê                                                            2
# Avelan, White, Cristalo                                        2
# MDF, vidro, espuma D18                                         2
# Cedro e Cedro Areia                                            2
# MDF, vidro, eucalipto, espuma D18                              2
# Name: count, dtype: int64

# %% [markdown]
# # Geoloc

# %%
geoloc = pd.read_csv(r'C:\Projetos\Nova pasta\seleme_wood\Dados\Processados\empresas_pinus_tabela.csv')
geoloc_munic = pd.read_csv(r'C:\Projetos\Nova pasta\seleme_wood\Dados\Processados\empresas_pinus_munic.csv')

# %%
import unicodedata

df_companies["nome_empresa_limpa"] = df_companies["nome_empresa"].str.rsplit("-", n=1).str[0].str.strip()
df_companies["cidade"] = df_companies["nome_empresa"].str.rsplit("-", n=1).str[-1].str.strip()

df_companies["cidade"] = (
    df_companies["nome_empresa"]
      .str.rsplit("-", n=1).str[-1].str.strip()
      .apply(lambda s: unicodedata.normalize("NFKD", s).encode("ascii", "ignore").decode("ascii"))
      .str.upper()
)

# %%
geoloc_munic = geoloc_munic[['nm_mun', 'nm_uf', 'nu_latitude', 'nu_longitude']]
df_companies = df_companies.merge(geoloc_munic, left_on='cidade', right_on='nm_mun', how='left')

# %%
df_companies = df_companies.drop(columns='cidade')

# %%
df_companies = df_companies.drop_duplicates()

# %%
df_companies
# Out:
#                                            nome_empresa  \
# 0     Esquadribras - Industria De Esquadrias Ltda - ...
# 6                           Klabin S.A. - Pouso Redondo
# 13    Sul America Industria De Molduras - Braco do N...
# 19        Blue Forest Industria E Comercio Ltda - Lages
# 28    Lavradora Racional De Madeiras Lavrama Sa - Ti...
# ...                                                 ...
# 3626                                   C.C.L. - Lajeado
# 3627                                   C.C.L. - Lajeado
# 3633                                    Homestar Brasil
# 3634                 Moveis Bosi Ltda - Bento Goncalves
# 3641                      ****** - Sao Joao do Polesine
#
#                                    url_site                 consulta  \
# 0          https://www.esquadribras.com.br/  painel de madeira pinus
# 6                    https://klabin.com.br/  painel de madeira pinus
# 13    https://www.sulamericamolduras.com.br  painel de madeira pinus
# 19                https://blueforest.com.br  painel de madeira pinus
# 28              https://www.lavrama.com.br/  painel de madeira pinus
# ...                                     ...                      ...
# 3626          https://www.cclajeado.com.br/  painel de madeira pinus
# 3627          https://www.cclajeado.com.br/  painel de madeira pinus
# 3633           https://www.homestar.com.br/  painel de madeira pinus
# 3634               https://www.bosi.com.br/  painel de madeira pinus
# 3641   https://saojoaodopolesine.rs.gov.br/  painel de madeira pinus
#
#      status_execucao                                        mensagem_pt  \
# 0              FOUND  Informações sobre produtos de madeira e painéi...
# 6              FOUND  Informações sobre produtos de madeira e painéi...
# 13             FOUND  Produtos relacionados a madeira e painéis de p...
# 19             FOUND  Informações sobre produtos de madeira pinus en...
# 28             FOUND  Empresa encontrada com informações sobre produ...
# ...              ...                                                ...
# 3626       NOT_FOUND  O site é de uma igreja e não há informações so...
# 3627       NOT_FOUND  O site é de uma igreja e não há informações so...
# 3633           FOUND  Produtos encontrados que imitam madeira, mas s...
# 3634           ERROR                 Erro ao processar: ValidationError
# 3641           ERROR                         Erro ao processar: OSError
#
#      trabalha_com_madeira trabalha_com_painel_pinus  flag_painel_pinus  \
# 0                     yes                       yes                  1
# 6                     yes                       yes                  1
# 13                    yes                       yes                  1
# 19                    yes                       yes                  1
# 28                    yes                       yes                  1
# ...                   ...                       ...                ...
# 3626                   no                        no                  0
# 3627                   no                        no                  0
# 3633                   no                        no                  0
# 3634              unknown                   unknown                  0
# 3641              unknown                   unknown                  0
#
#       confianca_madeira  confianca_painel_pinus  ... qtde_itens_total  \
# 0                   100                     100  ...                7
# 6                   100                     100  ...               11
# 13                  100                     100  ...                7
# 19                  100                     100  ...                7
# 28                  100                     100  ...                7
# ...                 ...                     ...  ...              ...
# 3626                  5                       5  ...                0
# 3627                  5                       5  ...                0
# 3633                  5                       5  ...                9
# 3634                  0                       0  ...                0
# 3641                  0                       0  ...                0
#
#      qtde_itens_madeira  qtde_itens_menciona_pinus  \
# 0                     4                          4
# 6                    11                         10
# 13                    7                          6
# 19                    7                          5
# 28                    7                          3
# ...                 ...                        ...
# 3626                  0                          0
# 3627                  0                          0
# 3633                  9                          0
# 3634                  0                          0
# 3641                  0                          0
#
#                            data_coleta  \
# 0     2026-01-15T12:28:56.581992+00:00
# 6     2026-01-15T12:48:01.397078+00:00
# 13    2026-01-15T12:52:46.184676+00:00
# 19    2026-01-15T12:54:53.981357+00:00
# 28    2026-01-15T13:08:08.993450+00:00
# ...                                ...
# 3626  2026-01-26T18:47:09.876283+00:00
# 3627  2026-01-26T18:47:09.876283+00:00
# 3633  2026-01-26T18:47:39.741201+00:00
# 3634  2026-01-26T17:25:11.781618+00:00
# 3641  2026-01-26T17:58:12.357214+00:00
#
#                                              tentativas  \
# 0     https://www.esquadribras.com.br/; https://www....
# 6     Navigated to https://klabin.com.br/; Clicked '...
# 13    Navigated to https://www.sulamericamolduras.co...
# 19    Navigated to https://blueforest.com.br; Clicke...
# 28    Navigated to https://www.lavrama.com.br/; Extr...
# ...                                                 ...
# 3626  Navigated to https://www.cclajeado.com.br/; Ac...
# 3627  Navigated to https://www.cclajeado.com.br/; Ac...
# 3633  Navigated to Homestar Brasil.; Clicked on 'Pro...
# 3634                                                NaN
# 3641                                                NaN
#
#                                nome_empresa_limpa                nm_mun  \
# 0     Esquadribras - Industria De Esquadrias Ltda        RIO DOS CEDROS
# 6                                     Klabin S.A.         POUSO REDONDO
# 13              Sul America Industria De Molduras        BRACO DO NORTE
# 19          Blue Forest Industria E Comercio Ltda                 LAGES
# 28      Lavradora Racional De Madeiras Lavrama Sa          TIMBO GRANDE
# ...                                           ...                   ...
# 3626                                       C.C.L.               LAJEADO
# 3627                                       C.C.L.               LAJEADO
# 3633                              Homestar Brasil                   NaN
# 3634                             Moveis Bosi Ltda       BENTO GONCALVES
# 3641                                       ******  SAO JOAO DO POLESINE
#
#                   nm_uf nu_latitude nu_longitude
# 0        Santa Catarina  -26.749130   -49.272379
# 6        Santa Catarina  -27.251086   -49.955652
# 13       Santa Catarina  -28.280039   -49.164548
# 19       Santa Catarina  -27.817259   -50.330222
# 28       Santa Catarina  -26.617828   -50.674674
# ...                 ...         ...          ...
# 3626          Tocantins   -9.744682   -48.358504
# 3627  Rio Grande do Sul  -29.465454   -51.967828
# 3633                NaN         NaN          NaN
# 3634  Rio Grande do Sul  -29.167402   -51.515560
# 3641  Rio Grande do Sul  -29.614676   -53.446350
#
# [647 rows x 22 columns]

# %%
"""
df_companies = df_companies.drop(columns=['nm_uf_y', 'nu_latitude_y', 'nu_longitude_y',"nm_mun_y"])
df_companies = df_companies.rename(columns={
    'nm_mun_x': 'nm_mun',
    'nm_uf_x': 'nm_uf',
    'nu_latitude_x': 'nu_latitude',
    'nu_longitude_x': 'nu_longitude',
    'url_site_x': 'url_site',
    'data_coleta_x': 'data_coleta',
})

"""
# Out:
# '\ndf_companies = df_companies.drop(columns=[\'nm_uf_y\', \'nu_latitude_y\', \'nu_longitude_y\',"nm_mun_y"])\ndf_companies = df_companies.rename(columns={\n    \'nm_mun_x\': \'nm_mun\',\n    \'nm_uf_x\': \'nm_uf\',\n    \'nu_latitude_x\': \'nu_latitude\',\n    \'nu_longitude_x\': \'nu_longitude\',\n    \'url_site_x\': \'url_site\',\n    \'data_coleta_x\': \'data_coleta\',\n})\n\n'

# %%
df_companies
# Out:
#                                            nome_empresa  \
# 0     Esquadribras - Industria De Esquadrias Ltda - ...
# 6                           Klabin S.A. - Pouso Redondo
# 13    Sul America Industria De Molduras - Braco do N...
# 19        Blue Forest Industria E Comercio Ltda - Lages
# 28    Lavradora Racional De Madeiras Lavrama Sa - Ti...
# ...                                                 ...
# 3626                                   C.C.L. - Lajeado
# 3627                                   C.C.L. - Lajeado
# 3633                                    Homestar Brasil
# 3634                 Moveis Bosi Ltda - Bento Goncalves
# 3641                      ****** - Sao Joao do Polesine
#
#                                    url_site                 consulta  \
# 0          https://www.esquadribras.com.br/  painel de madeira pinus
# 6                    https://klabin.com.br/  painel de madeira pinus
# 13    https://www.sulamericamolduras.com.br  painel de madeira pinus
# 19                https://blueforest.com.br  painel de madeira pinus
# 28              https://www.lavrama.com.br/  painel de madeira pinus
# ...                                     ...                      ...
# 3626          https://www.cclajeado.com.br/  painel de madeira pinus
# 3627          https://www.cclajeado.com.br/  painel de madeira pinus
# 3633           https://www.homestar.com.br/  painel de madeira pinus
# 3634               https://www.bosi.com.br/  painel de madeira pinus
# 3641   https://saojoaodopolesine.rs.gov.br/  painel de madeira pinus
#
#      status_execucao                                        mensagem_pt  \
# 0              FOUND  Informações sobre produtos de madeira e painéi...
# 6              FOUND  Informações sobre produtos de madeira e painéi...
# 13             FOUND  Produtos relacionados a madeira e painéis de p...
# 19             FOUND  Informações sobre produtos de madeira pinus en...
# 28             FOUND  Empresa encontrada com informações sobre produ...
# ...              ...                                                ...
# 3626       NOT_FOUND  O site é de uma igreja e não há informações so...
# 3627       NOT_FOUND  O site é de uma igreja e não há informações so...
# 3633           FOUND  Produtos encontrados que imitam madeira, mas s...
# 3634           ERROR                 Erro ao processar: ValidationError
# 3641           ERROR                         Erro ao processar: OSError
#
#      trabalha_com_madeira trabalha_com_painel_pinus  flag_painel_pinus  \
# 0                     yes                       yes                  1
# 6                     yes                       yes                  1
# 13                    yes                       yes                  1
# 19                    yes                       yes                  1
# 28                    yes                       yes                  1
# ...                   ...                       ...                ...
# 3626                   no                        no                  0
# 3627                   no                        no                  0
# 3633                   no                        no                  0
# 3634              unknown                   unknown                  0
# 3641              unknown                   unknown                  0
#
#       confianca_madeira  confianca_painel_pinus  ... qtde_itens_total  \
# 0                   100                     100  ...                7
# 6                   100                     100  ...               11
# 13                  100                     100  ...                7
# 19                  100                     100  ...                7
# 28                  100                     100  ...                7
# ...                 ...                     ...  ...              ...
# 3626                  5                       5  ...                0
# 3627                  5                       5  ...                0
# 3633                  5                       5  ...                9
# 3634                  0                       0  ...                0
# 3641                  0                       0  ...                0
#
#      qtde_itens_madeira  qtde_itens_menciona_pinus  \
# 0                     4                          4
# 6                    11                         10
# 13                    7                          6
# 19                    7                          5
# 28                    7                          3
# ...                 ...                        ...
# 3626                  0                          0
# 3627                  0                          0
# 3633                  9                          0
# 3634                  0                          0
# 3641                  0                          0
#
#                            data_coleta  \
# 0     2026-01-15T12:28:56.581992+00:00
# 6     2026-01-15T12:48:01.397078+00:00
# 13    2026-01-15T12:52:46.184676+00:00
# 19    2026-01-15T12:54:53.981357+00:00
# 28    2026-01-15T13:08:08.993450+00:00
# ...                                ...
# 3626  2026-01-26T18:47:09.876283+00:00
# 3627  2026-01-26T18:47:09.876283+00:00
# 3633  2026-01-26T18:47:39.741201+00:00
# 3634  2026-01-26T17:25:11.781618+00:00
# 3641  2026-01-26T17:58:12.357214+00:00
#
#                                              tentativas  \
# 0     https://www.esquadribras.com.br/; https://www....
# 6     Navigated to https://klabin.com.br/; Clicked '...
# 13    Navigated to https://www.sulamericamolduras.co...
# 19    Navigated to https://blueforest.com.br; Clicke...
# 28    Navigated to https://www.lavrama.com.br/; Extr...
# ...                                                 ...
# 3626  Navigated to https://www.cclajeado.com.br/; Ac...
# 3627  Navigated to https://www.cclajeado.com.br/; Ac...
# 3633  Navigated to Homestar Brasil.; Clicked on 'Pro...
# 3634                                                NaN
# 3641                                                NaN
#
#                                nome_empresa_limpa                nm_mun  \
# 0     Esquadribras - Industria De Esquadrias Ltda        RIO DOS CEDROS
# 6                                     Klabin S.A.         POUSO REDONDO
# 13              Sul America Industria De Molduras        BRACO DO NORTE
# 19          Blue Forest Industria E Comercio Ltda                 LAGES
# 28      Lavradora Racional De Madeiras Lavrama Sa          TIMBO GRANDE
# ...                                           ...                   ...
# 3626                                       C.C.L.               LAJEADO
# 3627                                       C.C.L.               LAJEADO
# 3633                              Homestar Brasil                   NaN
# 3634                             Moveis Bosi Ltda       BENTO GONCALVES
# 3641                                       ******  SAO JOAO DO POLESINE
#
#                   nm_uf nu_latitude nu_longitude
# 0        Santa Catarina  -26.749130   -49.272379
# 6        Santa Catarina  -27.251086   -49.955652
# 13       Santa Catarina  -28.280039   -49.164548
# 19       Santa Catarina  -27.817259   -50.330222
# 28       Santa Catarina  -26.617828   -50.674674
# ...                 ...         ...          ...
# 3626          Tocantins   -9.744682   -48.358504
# 3627  Rio Grande do Sul  -29.465454   -51.967828
# 3633                NaN         NaN          NaN
# 3634  Rio Grande do Sul  -29.167402   -51.515560
# 3641  Rio Grande do Sul  -29.614676   -53.446350
#
# [647 rows x 22 columns]

# %% [markdown]
# # Save

# %%
df_itens.to_csv(r"C:\Projetos\Nova pasta\seleme_wood\App\items_final.csv", index=False)

# %%
df_companies.to_csv(r"C:\Projetos\Nova pasta\seleme_wood\App\companies_final.csv", index=False)

# %% [markdown]
# # Análises

# %%
import pandas as pd 
df_itens = pd.read_csv(r"C:\Projetos\Nova pasta\seleme_wood\App\items_final.csv")
df_companies = pd.read_csv(r"C:\Projetos\Nova pasta\seleme_wood\App\companies_final.csv")

# %%
df_itens
# Out:
#                                        nome_empresa  \
# 0     Blue Forest Industria E Comercio Ltda - Lages
# 1     Blue Forest Industria E Comercio Ltda - Lages
# 2     Blue Forest Industria E Comercio Ltda - Lages
# 3     Blue Forest Industria E Comercio Ltda - Lages
# 4     Blue Forest Industria E Comercio Ltda - Lages
# ...                                             ...
# 1899  Trianon Industria E Comercio Ltda - Garibaldi
# 1900  Trianon Industria E Comercio Ltda - Garibaldi
# 1901  Trianon Industria E Comercio Ltda - Garibaldi
# 1902  Trianon Industria E Comercio Ltda - Garibaldi
# 1903                                 Villa Imperial
#
#                                url_site                       data_coleta  \
# 0             https://blueforest.com.br  2026-01-15T12:54:53.981357+00:00
# 1             https://blueforest.com.br  2026-01-15T12:54:53.981357+00:00
# 2             https://blueforest.com.br  2026-01-15T12:54:53.981357+00:00
# 3             https://blueforest.com.br  2026-01-15T12:54:53.981357+00:00
# 4             https://blueforest.com.br  2026-01-15T12:54:53.981357+00:00
# ...                                 ...                               ...
# 1899    https://www.trianongroup.com.br  2026-01-26T17:33:56.339646+00:00
# 1900    https://www.trianongroup.com.br  2026-01-26T17:33:56.339646+00:00
# 1901    https://www.trianongroup.com.br  2026-01-26T17:33:56.339646+00:00
# 1902    https://www.trianongroup.com.br  2026-01-26T17:33:56.339646+00:00
# 1903  https://www.villaimperial.com.br/  2026-01-26T18:10:09.589325+00:00
#
#                              categoria_produto  \
# 0                                CERCAS BRUTAS
# 1                               CERCAS GÓTICAS
# 2                               CERCAS GÓTICAS
# 3                                      ESTACAS
# 4                                   BALAÚSTRES
# ...                                        ...
# 1899          Cápsulas e Screwcaps para vinhos
# 1900          Cápsulas e Screwcaps para vinhos
# 1901  Gabietas, cápsulas e Tampas de espumante
# 1902                       Esferas de Concreto
# 1903                        Fechamento Externo
#
#                                  nome_produto       material  \
# 0            CERCAS BRUTAS DE PINUS "DOG EAR"          PINUS
# 1              CERCAS GÓTICAS BRUTAS DE PINUS          PINUS
# 2          CERCAS GÓTICAS APLAINADAS DE PINUS          PINUS
# 3                 ESTACAS APLAINADAS DE PINUS          PINUS
# 4              BALAÚSTRES APLAINADOS DE PINUS          PINUS
# ...                                       ...            ...
# 1899           Cápsulas para Vinho em Estanho        Estanho
# 1900  Tampas De Alumínio Com Rosca (Screwcap)       Alumínio
# 1901                                 Gabietas            NaN
# 1902                      Esferas de Concreto  Concreto leve
# 1903                        Chapa de MDF 3 mm            MDF
#
#      relacionado_madeira menciona_pinus  \
# 0                    yes            yes
# 1                    yes            yes
# 2                    yes            yes
# 3                    yes            yes
# 4                    yes            yes
# ...                  ...            ...
# 1899                  no             no
# 1900                  no             no
# 1901                  no             no
# 1902                  no             no
# 1903                  no             no
#
#                                  fonte_indicio  \
# 0                              Mercado Externo
# 1                              Mercado Externo
# 2                              Mercado Externo
# 3                              Mercado Externo
# 4                              Mercado Externo
# ...                                        ...
# 1899          Cápsulas e Screwcaps para vinhos
# 1900          Cápsulas e Screwcaps para vinhos
# 1901  Gabietas, cápsulas e Tampas de espumante
# 1902                       Esferas de Concreto
# 1903                Madeira de reflorestamento
#
#                         categoria_produto_norm categoria_produto_grupo  \
# 0                                cercas brutas                  outros
# 1                               cercas goticas                  outros
# 2                               cercas goticas                  outros
# 3                                      estacas                  outros
# 4                                   balaustres                  outros
# ...                                        ...                     ...
# 1899          capsulas e screwcaps para vinhos                  outros
# 1900          capsulas e screwcaps para vinhos                  outros
# 1901  gabietas, capsulas e tampas de espumante                  outros
# 1902                       esferas de concreto                  outros
# 1903                        fechamento externo                  outros
#
#       material_norm    material_grupo
# 0             pinus             Pinus
# 1             pinus             Pinus
# 2             pinus             Pinus
# 3             pinus             Pinus
# 4             pinus             Pinus
# ...             ...               ...
# 1899        estanho           Estanho
# 1900       aluminio          Aluminio
# 1901            NaN  Não especificado
# 1902  concreto leve     Concreto leve
# 1903            mdf               Mdf
#
# [1904 rows x 13 columns]

# %%
df_analise = pd.merge(df_itens, df_companies, left_on=["nome_empresa", "url_site", "data_coleta"], right_on=["nome_empresa", "url_site", "data_coleta"], how="inner")
df_analise = df_analise.drop_duplicates()

# %%
df_analise
# Out:
#                                        nome_empresa  \
# 0     Blue Forest Industria E Comercio Ltda - Lages
# 1     Blue Forest Industria E Comercio Ltda - Lages
# 2     Blue Forest Industria E Comercio Ltda - Lages
# 3     Blue Forest Industria E Comercio Ltda - Lages
# 4     Blue Forest Industria E Comercio Ltda - Lages
# ...                                             ...
# 1997  Trianon Industria E Comercio Ltda - Garibaldi
# 1998  Trianon Industria E Comercio Ltda - Garibaldi
# 1999  Trianon Industria E Comercio Ltda - Garibaldi
# 2000  Trianon Industria E Comercio Ltda - Garibaldi
# 2001                                 Villa Imperial
#
#                                url_site                       data_coleta  \
# 0             https://blueforest.com.br  2026-01-15T12:54:53.981357+00:00
# 1             https://blueforest.com.br  2026-01-15T12:54:53.981357+00:00
# 2             https://blueforest.com.br  2026-01-15T12:54:53.981357+00:00
# 3             https://blueforest.com.br  2026-01-15T12:54:53.981357+00:00
# 4             https://blueforest.com.br  2026-01-15T12:54:53.981357+00:00
# ...                                 ...                               ...
# 1997    https://www.trianongroup.com.br  2026-01-26T17:33:56.339646+00:00
# 1998    https://www.trianongroup.com.br  2026-01-26T17:33:56.339646+00:00
# 1999    https://www.trianongroup.com.br  2026-01-26T17:33:56.339646+00:00
# 2000    https://www.trianongroup.com.br  2026-01-26T17:33:56.339646+00:00
# 2001  https://www.villaimperial.com.br/  2026-01-26T18:10:09.589325+00:00
#
#                              categoria_produto  \
# 0                                CERCAS BRUTAS
# 1                               CERCAS GÓTICAS
# 2                               CERCAS GÓTICAS
# 3                                      ESTACAS
# 4                                   BALAÚSTRES
# ...                                        ...
# 1997          Cápsulas e Screwcaps para vinhos
# 1998          Cápsulas e Screwcaps para vinhos
# 1999  Gabietas, cápsulas e Tampas de espumante
# 2000                       Esferas de Concreto
# 2001                        Fechamento Externo
#
#                                  nome_produto       material  \
# 0            CERCAS BRUTAS DE PINUS "DOG EAR"          PINUS
# 1              CERCAS GÓTICAS BRUTAS DE PINUS          PINUS
# 2          CERCAS GÓTICAS APLAINADAS DE PINUS          PINUS
# 3                 ESTACAS APLAINADAS DE PINUS          PINUS
# 4              BALAÚSTRES APLAINADOS DE PINUS          PINUS
# ...                                       ...            ...
# 1997           Cápsulas para Vinho em Estanho        Estanho
# 1998  Tampas De Alumínio Com Rosca (Screwcap)       Alumínio
# 1999                                 Gabietas            NaN
# 2000                      Esferas de Concreto  Concreto leve
# 2001                        Chapa de MDF 3 mm            MDF
#
#      relacionado_madeira menciona_pinus  \
# 0                    yes            yes
# 1                    yes            yes
# 2                    yes            yes
# 3                    yes            yes
# 4                    yes            yes
# ...                  ...            ...
# 1997                  no             no
# 1998                  no             no
# 1999                  no             no
# 2000                  no             no
# 2001                  no             no
#
#                                  fonte_indicio  \
# 0                              Mercado Externo
# 1                              Mercado Externo
# 2                              Mercado Externo
# 3                              Mercado Externo
# 4                              Mercado Externo
# ...                                        ...
# 1997          Cápsulas e Screwcaps para vinhos
# 1998          Cápsulas e Screwcaps para vinhos
# 1999  Gabietas, cápsulas e Tampas de espumante
# 2000                       Esferas de Concreto
# 2001                Madeira de reflorestamento
#
#                         categoria_produto_norm  ...  \
# 0                                cercas brutas  ...
# 1                               cercas goticas  ...
# 2                               cercas goticas  ...
# 3                                      estacas  ...
# 4                                   balaustres  ...
# ...                                        ...  ...
# 1997          capsulas e screwcaps para vinhos  ...
# 1998          capsulas e screwcaps para vinhos  ...
# 1999  gabietas, capsulas e tampas de espumante  ...
# 2000                       esferas de concreto  ...
# 2001                        fechamento externo  ...
#
#                                        resumo_materiais qtde_itens_total  \
# 0     A empresa oferece diversos produtos de madeira...                7
# 1     A empresa oferece diversos produtos de madeira...                7
# 2     A empresa oferece diversos produtos de madeira...                7
# 3     A empresa oferece diversos produtos de madeira...                7
# 4     A empresa oferece diversos produtos de madeira...                7
# ...                                                 ...              ...
# 1997  Carvalho (Oak), Concreto leve (Light Concrete)...               15
# 1998  Carvalho (Oak), Concreto leve (Light Concrete)...               15
# 1999  Carvalho (Oak), Concreto leve (Light Concrete)...               15
# 2000  Carvalho (Oak), Concreto leve (Light Concrete)...               15
# 2001  Estrutura de madeira de eucalipto proveniente ...                2
#
#      qtde_itens_madeira qtde_itens_menciona_pinus  \
# 0                     7                         5
# 1                     7                         5
# 2                     7                         5
# 3                     7                         5
# 4                     7                         5
# ...                 ...                       ...
# 1997                  1                         0
# 1998                  1                         0
# 1999                  1                         0
# 2000                  1                         0
# 2001                  1                         0
#
#                                              tentativas  \
# 0     Navigated to https://blueforest.com.br; Clicke...
# 1     Navigated to https://blueforest.com.br; Clicke...
# 2     Navigated to https://blueforest.com.br; Clicke...
# 3     Navigated to https://blueforest.com.br; Clicke...
# 4     Navigated to https://blueforest.com.br; Clicke...
# ...                                                 ...
# 1997  Navigated to https://www.trianongroup.com.br/p...
# 1998  Navigated to https://www.trianongroup.com.br/p...
# 1999  Navigated to https://www.trianongroup.com.br/p...
# 2000  Navigated to https://www.trianongroup.com.br/p...
# 2001  Navigated to https://www.villaimperial.com.br/...
#
#                          nome_empresa_limpa     nm_mun              nm_uf  \
# 0     Blue Forest Industria E Comercio Ltda      LAGES     Santa Catarina
# 1     Blue Forest Industria E Comercio Ltda      LAGES     Santa Catarina
# 2     Blue Forest Industria E Comercio Ltda      LAGES     Santa Catarina
# 3     Blue Forest Industria E Comercio Ltda      LAGES     Santa Catarina
# 4     Blue Forest Industria E Comercio Ltda      LAGES     Santa Catarina
# ...                                     ...        ...                ...
# 1997      Trianon Industria E Comercio Ltda  GARIBALDI  Rio Grande do Sul
# 1998      Trianon Industria E Comercio Ltda  GARIBALDI  Rio Grande do Sul
# 1999      Trianon Industria E Comercio Ltda  GARIBALDI  Rio Grande do Sul
# 2000      Trianon Industria E Comercio Ltda  GARIBALDI  Rio Grande do Sul
# 2001                         Villa Imperial        NaN                NaN
#
#       nu_latitude  nu_longitude
# 0      -27.817259    -50.330222
# 1      -27.817259    -50.330222
# 2      -27.817259    -50.330222
# 3      -27.817259    -50.330222
# 4      -27.817259    -50.330222
# ...           ...           ...
# 1997   -29.254549    -51.529548
# 1998   -29.254549    -51.529548
# 1999   -29.254549    -51.529548
# 2000   -29.254549    -51.529548
# 2001          NaN           NaN
#
# [1993 rows x 32 columns]

# %%
df_analise2 =df_analise[(df_analise['status_execucao'] == "FOUND") & (df_analise['menciona_pinus'] == "yes")]
df_analise2 = df_analise2.drop_duplicates()
df_analise2 = df_analise2[df_analise2['nm_uf'] != 'Paraíba']
df_analise2
#df_analise['status_execucao'].value_counts()
# Out:
#                                        nome_empresa  \
# 0     Blue Forest Industria E Comercio Ltda - Lages
# 1     Blue Forest Industria E Comercio Ltda - Lages
# 2     Blue Forest Industria E Comercio Ltda - Lages
# 3     Blue Forest Industria E Comercio Ltda - Lages
# 4     Blue Forest Industria E Comercio Ltda - Lages
# ...                                             ...
# 1387   Totalita Industria De Moveis - Restinga Seca
# 1388   Totalita Industria De Moveis - Restinga Seca
# 1389   Totalita Industria De Moveis - Restinga Seca
# 1390   Totalita Industria De Moveis - Restinga Seca
# 1391   Totalita Industria De Moveis - Restinga Seca
#
#                        url_site                       data_coleta  \
# 0     https://blueforest.com.br  2026-01-15T12:54:53.981357+00:00
# 1     https://blueforest.com.br  2026-01-15T12:54:53.981357+00:00
# 2     https://blueforest.com.br  2026-01-15T12:54:53.981357+00:00
# 3     https://blueforest.com.br  2026-01-15T12:54:53.981357+00:00
# 4     https://blueforest.com.br  2026-01-15T12:54:53.981357+00:00
# ...                         ...                               ...
# 1387        www.totalita.com.br  2026-01-26T18:48:05.012235+00:00
# 1388        www.totalita.com.br  2026-01-26T18:48:05.012235+00:00
# 1389        www.totalita.com.br  2026-01-26T18:48:05.012235+00:00
# 1390        www.totalita.com.br  2026-01-26T18:48:05.012235+00:00
# 1391        www.totalita.com.br  2026-01-26T18:48:05.012235+00:00
#
#      categoria_produto                        nome_produto      material  \
# 0        CERCAS BRUTAS    CERCAS BRUTAS DE PINUS "DOG EAR"         PINUS
# 1       CERCAS GÓTICAS      CERCAS GÓTICAS BRUTAS DE PINUS         PINUS
# 2       CERCAS GÓTICAS  CERCAS GÓTICAS APLAINADAS DE PINUS         PINUS
# 3              ESTACAS         ESTACAS APLAINADAS DE PINUS         PINUS
# 4           BALAÚSTRES      BALAÚSTRES APLAINADOS DE PINUS         PINUS
# ...                ...                                 ...           ...
# 1387               NaN                       Tota O 001/03  Pinus ou MDF
# 1388               NaN                               B 087  Pinus ou MDF
# 1389               NaN                               C 035  Pinus ou MDF
# 1390               NaN                               B 014  Pinus ou MDF
# 1391               NaN                               B 090  Pinus ou MDF
#
#      relacionado_madeira menciona_pinus    fonte_indicio  \
# 0                    yes            yes  Mercado Externo
# 1                    yes            yes  Mercado Externo
# 2                    yes            yes  Mercado Externo
# 3                    yes            yes  Mercado Externo
# 4                    yes            yes  Mercado Externo
# ...                  ...            ...              ...
# 1387                 yes            yes    Tota O 001/03
# 1388                 yes            yes            B 087
# 1389                 yes            yes            C 035
# 1390                 yes            yes            B 014
# 1391                 yes            yes            B 090
#
#      categoria_produto_norm  ...  \
# 0             cercas brutas  ...
# 1            cercas goticas  ...
# 2            cercas goticas  ...
# 3                   estacas  ...
# 4                balaustres  ...
# ...                     ...  ...
# 1387                    NaN  ...
# 1388                    NaN  ...
# 1389                    NaN  ...
# 1390                    NaN  ...
# 1391                    NaN  ...
#
#                                        resumo_materiais qtde_itens_total  \
# 0     A empresa oferece diversos produtos de madeira...                7
# 1     A empresa oferece diversos produtos de madeira...                7
# 2     A empresa oferece diversos produtos de madeira...                7
# 3     A empresa oferece diversos produtos de madeira...                7
# 4     A empresa oferece diversos produtos de madeira...                7
# ...                                                 ...              ...
# 1387  A empresa utiliza madeira de Pinus e MDF em se...                6
# 1388  A empresa utiliza madeira de Pinus e MDF em se...                6
# 1389  A empresa utiliza madeira de Pinus e MDF em se...                6
# 1390  A empresa utiliza madeira de Pinus e MDF em se...                6
# 1391  A empresa utiliza madeira de Pinus e MDF em se...                6
#
#      qtde_itens_madeira qtde_itens_menciona_pinus  \
# 0                     7                         5
# 1                     7                         5
# 2                     7                         5
# 3                     7                         5
# 4                     7                         5
# ...                 ...                       ...
# 1387                  6                         6
# 1388                  6                         6
# 1389                  6                         6
# 1390                  6                         6
# 1391                  6                         6
#
#                                              tentativas  \
# 0     Navigated to https://blueforest.com.br; Clicke...
# 1     Navigated to https://blueforest.com.br; Clicke...
# 2     Navigated to https://blueforest.com.br; Clicke...
# 3     Navigated to https://blueforest.com.br; Clicke...
# 4     Navigated to https://blueforest.com.br; Clicke...
# ...                                                 ...
# 1387  Navigated to www.totalita.com.br and found exp...
# 1388  Navigated to www.totalita.com.br and found exp...
# 1389  Navigated to www.totalita.com.br and found exp...
# 1390  Navigated to www.totalita.com.br and found exp...
# 1391  Navigated to www.totalita.com.br and found exp...
#
#                          nome_empresa_limpa         nm_mun              nm_uf  \
# 0     Blue Forest Industria E Comercio Ltda          LAGES     Santa Catarina
# 1     Blue Forest Industria E Comercio Ltda          LAGES     Santa Catarina
# 2     Blue Forest Industria E Comercio Ltda          LAGES     Santa Catarina
# 3     Blue Forest Industria E Comercio Ltda          LAGES     Santa Catarina
# 4     Blue Forest Industria E Comercio Ltda          LAGES     Santa Catarina
# ...                                     ...            ...                ...
# 1387           Totalita Industria De Moveis  RESTINGA SECA  Rio Grande do Sul
# 1388           Totalita Industria De Moveis  RESTINGA SECA  Rio Grande do Sul
# 1389           Totalita Industria De Moveis  RESTINGA SECA  Rio Grande do Sul
# 1390           Totalita Industria De Moveis  RESTINGA SECA  Rio Grande do Sul
# 1391           Totalita Industria De Moveis  RESTINGA SECA  Rio Grande do Sul
#
#       nu_latitude  nu_longitude
# 0      -27.817259    -50.330222
# 1      -27.817259    -50.330222
# 2      -27.817259    -50.330222
# 3      -27.817259    -50.330222
# 4      -27.817259    -50.330222
# ...           ...           ...
# 1387   -29.813949    -53.370569
# 1388   -29.813949    -53.370569
# 1389   -29.813949    -53.370569
# 1390   -29.813949    -53.370569
# 1391   -29.813949    -53.370569
#
# [150 rows x 32 columns]

# %%
print("Número de empresas únicas encontradas que possuem site no formato de portfólio:", df_analise['nome_empresa'].nunique())
# Out:
# Número de empresas únicas encontradas que possuem site no formato de portfólio: 190

# %%
df_companies['nm_uf'].value_counts()
# Out:
# nm_uf
# Santa Catarina        217
# Rio Grande do Sul     198
# Paraná                177
# Tocantins               5
# Alagoas                 4
# São Paulo               4
# Minas Gerais            4
# Paraíba                 3
# Ceará                   3
# Goiás                   1
# Espírito Santo          1
# Mato Grosso do Sul      1
# Pernambuco              1
# Bahia                   1
# Name: count, dtype: int64

# %%
df_companies[df_companies['flag_painel_pinus'] == 1]['nm_uf'].value_counts()
# Out:
# nm_uf
# Santa Catarina       31
# Rio Grande do Sul    16
# Paraná               12
# Paraíba               2
# Name: count, dtype: int64

# %%
print("Número de empresas únicas que trabalham com Pinus:", df_analise2['nome_empresa'].nunique())
# Out:
# Número de empresas únicas que trabalham com Pinus: 61

# %%
print("Percetual de empresas que trabalham com Pinus entre as que possuem portfólio: {:.2f}%".format(
    (df_analise2['nome_empresa'].nunique() / df_analise['nome_empresa'].nunique()) * 100
))
# Out:
# Percetual de empresas que trabalham com Pinus entre as que possuem portfólio: 32.11%

# %%
# ...existing code...
print(
    "Distribuição de empresas por UF:",
    df_analise.drop_duplicates(subset="nome_empresa")["nm_uf"].value_counts()
)
# ...existing code...
# Out:
# Distribuição de empresas por UF: nm_uf
# Santa Catarina       81
# Rio Grande do Sul    56
# Paraná               31
# Paraíba               2
# São Paulo             2
# Alagoas               1
# Ceará                 1
# Pernambuco            1
# Name: count, dtype: int64

# %%
# ...existing code...
print(
    "Distribuição de empresas por UF:",
    df_analise2.drop_duplicates(subset="nome_empresa")["nm_uf"].value_counts()
)
# ...existing code...
# Out:
# Distribuição de empresas por UF: nm_uf
# Santa Catarina       31
# Rio Grande do Sul    14
# Paraná               10
# Name: count, dtype: int64

# %%
df_analise2['categoria_produto_grupo'].value_counts() #analisar estes outros, para classificar melhor
# Out:
# categoria_produto_grupo
# outros     101
# madeira     28
# painel      11
# portas      10
# Name: count, dtype: int64

# %%
df_analise2['categoria_produto'].value_counts() #analisar estes outros, para classificar melhor
# Out:
# categoria_produto
# Madeira                 8
# Móveis                  6
# Madeira Serrada         6
# Papel-cartão            6
# Portas                  5
#                        ..
# Área Externa            1
# Estrutura               1
# Cavilhas                1
# Acabamentos Internos    1
# Beliches                1
# Name: count, Length: 66, dtype: int64

# %%
print("quantidade de produtos que mencionam pinus:", len(df_analise2))
# Out:
# quantidade de produtos que mencionam pinus: 122

# %%
df_analise2[df_analise2['nome_empresa_limpa'] == "Fabrica De Moveis Rorato"]
# Out:
#                             nome_empresa                      url_site  \
# 1121  Fabrica De Moveis Rorato - Araruna  https://www.ajrorato.ind.br/
# 1125  Fabrica De Moveis Rorato - Araruna  https://www.ajrorato.ind.br/
# 1129  Fabrica De Moveis Rorato - Araruna  https://www.ajrorato.ind.br/
# 1133  Fabrica De Moveis Rorato - Araruna  https://www.ajrorato.ind.br/
# 1137  Fabrica De Moveis Rorato - Araruna  https://www.ajrorato.ind.br/
# 1141  Fabrica De Moveis Rorato - Araruna  https://www.ajrorato.ind.br/
# 1145  Fabrica De Moveis Rorato - Araruna  https://www.ajrorato.ind.br/
# 1149  Fabrica De Moveis Rorato - Araruna  https://www.ajrorato.ind.br/
# 1153  Fabrica De Moveis Rorato - Araruna  https://www.ajrorato.ind.br/
# 1157  Fabrica De Moveis Rorato - Araruna  https://www.ajrorato.ind.br/
#
#                            data_coleta categoria_produto  \
# 1121  2026-01-26T12:26:53.444055+00:00          COZINHAS
# 1125  2026-01-26T12:26:53.444055+00:00          COZINHAS
# 1129  2026-01-26T12:26:53.444055+00:00          COZINHAS
# 1133  2026-01-26T12:26:53.444055+00:00          COZINHAS
# 1137  2026-01-26T12:26:53.444055+00:00          COZINHAS
# 1141  2026-01-26T12:26:53.444055+00:00        LAVANDERIA
# 1145  2026-01-26T12:26:53.444055+00:00        LAVANDERIA
# 1149  2026-01-26T12:26:53.444055+00:00        LAVANDERIA
# 1153  2026-01-26T12:26:53.444055+00:00        LAVANDERIA
# 1157  2026-01-26T12:26:53.444055+00:00        LAVANDERIA
#
#                                      nome_produto  \
# 1121                       ARMÁRIO ATENAS 192,2CM
# 1125                       ARMÁRIO ATENAS 154,2CM
# 1129                       ARMÁRIO ATENAS 134,2CM
# 1133                      ARMÁRIO VALENZA 144,2CM
# 1137                       ARMÁRIO TÓQUIO 174,2CM
# 1141  KIT LAVANDERIA AMÉLIA TANQUE SIMPLES 43,5CM
# 1145                ARMÁRIO AÉREO 2 PORTAS 56,5CM
# 1149               ARMÁRIO AÉREO 3 PORTAS 106,0CM
# 1153     KIT LAVANDERIA AMÉLIA TANQUE DUPLO 110CM
# 1157    KIT LAVANDERIA AMÉLIA TANQUE SIMPLES 61CM
#
#                                                material relacionado_madeira  \
# 1121  Estrutura reforçada de madeira pinus de reflor...                 yes
# 1125  Estrutura reforçada de madeira pinus de reflor...                 yes
# 1129  Estrutura reforçada de madeira pinus de reflor...                 yes
# 1133  Estrutura reforçada de madeira pinus de reflor...                 yes
# 1137  Estrutura reforçada de madeira pinus de reflor...                 yes
# 1141  Armário com estrutura reforçada de madeira pin...                 yes
# 1145  Armário com estrutura reforçada de madeira pin...                 yes
# 1149  Armário com estrutura reforçada de madeira pin...                 yes
# 1153  Armário com estrutura reforçada de madeira pin...                 yes
# 1157  Armário com estrutura reforçada de madeira pin...                 yes
#
#      menciona_pinus fonte_indicio categoria_produto_norm  ...  \
# 1121            yes      COZINHAS               cozinhas  ...
# 1125            yes      COZINHAS               cozinhas  ...
# 1129            yes      COZINHAS               cozinhas  ...
# 1133            yes      COZINHAS               cozinhas  ...
# 1137            yes      COZINHAS               cozinhas  ...
# 1141            yes    LAVANDERIA             lavanderia  ...
# 1145            yes    LAVANDERIA             lavanderia  ...
# 1149            yes    LAVANDERIA             lavanderia  ...
# 1153            yes    LAVANDERIA             lavanderia  ...
# 1157            yes    LAVANDERIA             lavanderia  ...
#
#                                        resumo_materiais qtde_itens_total  \
# 1121  A empresa utiliza madeira de pinus de reflores...               10
# 1125  A empresa utiliza madeira de pinus de reflores...               10
# 1129  A empresa utiliza madeira de pinus de reflores...               10
# 1133  A empresa utiliza madeira de pinus de reflores...               10
# 1137  A empresa utiliza madeira de pinus de reflores...               10
# 1141  A empresa utiliza madeira de pinus de reflores...               10
# 1145  A empresa utiliza madeira de pinus de reflores...               10
# 1149  A empresa utiliza madeira de pinus de reflores...               10
# 1153  A empresa utiliza madeira de pinus de reflores...               10
# 1157  A empresa utiliza madeira de pinus de reflores...               10
#
#      qtde_itens_madeira qtde_itens_menciona_pinus  \
# 1121                 10                        10
# 1125                 10                        10
# 1129                 10                        10
# 1133                 10                        10
# 1137                 10                        10
# 1141                 10                        10
# 1145                 10                        10
# 1149                 10                        10
# 1153                 10                        10
# 1157                 10                        10
#
#                                              tentativas  \
# 1121  Navigated to https://www.ajrorato.ind.br/; Ext...
# 1125  Navigated to https://www.ajrorato.ind.br/; Ext...
# 1129  Navigated to https://www.ajrorato.ind.br/; Ext...
# 1133  Navigated to https://www.ajrorato.ind.br/; Ext...
# 1137  Navigated to https://www.ajrorato.ind.br/; Ext...
# 1141  Navigated to https://www.ajrorato.ind.br/; Ext...
# 1145  Navigated to https://www.ajrorato.ind.br/; Ext...
# 1149  Navigated to https://www.ajrorato.ind.br/; Ext...
# 1153  Navigated to https://www.ajrorato.ind.br/; Ext...
# 1157  Navigated to https://www.ajrorato.ind.br/; Ext...
#
#             nome_empresa_limpa   nm_mun   nm_uf  nu_latitude  nu_longitude
# 1121  Fabrica De Moveis Rorato  ARARUNA  Paraná   -23.928201    -52.499618
# 1125  Fabrica De Moveis Rorato  ARARUNA  Paraná   -23.928201    -52.499618
# 1129  Fabrica De Moveis Rorato  ARARUNA  Paraná   -23.928201    -52.499618
# 1133  Fabrica De Moveis Rorato  ARARUNA  Paraná   -23.928201    -52.499618
# 1137  Fabrica De Moveis Rorato  ARARUNA  Paraná   -23.928201    -52.499618
# 1141  Fabrica De Moveis Rorato  ARARUNA  Paraná   -23.928201    -52.499618
# 1145  Fabrica De Moveis Rorato  ARARUNA  Paraná   -23.928201    -52.499618
# 1149  Fabrica De Moveis Rorato  ARARUNA  Paraná   -23.928201    -52.499618
# 1153  Fabrica De Moveis Rorato  ARARUNA  Paraná   -23.928201    -52.499618
# 1157  Fabrica De Moveis Rorato  ARARUNA  Paraná   -23.928201    -52.499618
#
# [10 rows x 32 columns]

# %%
df_analise2.groupby('categoria_produto_grupo').size().sort_values(ascending=False).plot(kind='bar', title='Quantidade de Produtos por Categoria', figsize=(12, 6))
# Out:
# <Axes: title={'center': 'Quantidade de Produtos por Categoria'}, xlabel='categoria_produto_grupo'>

# %%
# ...existing code...
media_produtos_por_empresa = df_analise2.groupby('nome_empresa_limpa').size().mean()
print("Média de produtos por empresa:", media_produtos_por_empresa)
# ...existing code...
# Out:
# Média de produtos por empresa: 2.6315789473684212

# %%
df_analise2.groupby('nome_empresa_limpa').size().sort_values(ascending=False).plot(kind='bar', title='Quantidade de Produtos por Empresa', figsize=(12, 6))
